# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url_data=r'https://raw.githubusercontent.com/astroclubiitk/computational-astrophysics/main/Week-1/Assignment/Astrosat_Catalog.csv'
df=pd.read_csv(url_data)
df.head()
# Out:
#           ra        dec       Source_Name      SIMBAD_Name Final_Type  \
# 0   8.233750 -73.805278  J0032.9-7348      RX J0032.9-7348       HMXB
# 1  11.210000  33.021389   0042+323              4U 0042+32       LMXB
# 2  12.260417 -72.847778  J0049-729         RX J0049.0-7250       HMXB
# 3  12.373333 -73.182222  J0049-732             [MA93]  300       HMXB
# 4  12.686250 -73.268056  J0050.7-7316            V* DZ Tuc       HMXB
#
#    Astrosat_Flag
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.loc[df['ra']>180,'ra1']=(df['ra']-360)*np.pi/180
df.loc[df['ra']<=180,'ra1']=(df['ra']*np.pi/180)
df.insert(7,'dec2',df['dec']*np.pi/180)
h=df[df.Final_Type=='HMXB']
l=df[df.Final_Type=='LMXB']
fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1,sharex=True)
ax1.plot(h.ra,h.dec,'k-',label='HMXB')
ax1.set_title('HMXB(High Mass X-ray Binaries)')
ax1.set_xlabel('ra')
ax1.set_ylabel('dec')
ax1.legend(loc=4)            
#plotting axis1
ax2.plot(l.ra,l.dec,'b',label='LMXB')
ax2.set_title('(Low Mass X-Ray Binaries)')
ax2.set_xlabel('ra')
ax2.set_ylabel('dec')
plt.legend(loc=4)
plt.tight_layout()
plt.show()
#plotting axis2

# %%
h
# Out:
#              ra        dec       Source_Name      SIMBAD_Name Final_Type  \
# 0      8.233750 -73.805278  J0032.9-7348      RX J0032.9-7348       HMXB
# 2     12.260417 -72.847778  J0049-729         RX J0049.0-7250       HMXB
# 3     12.373333 -73.182222  J0049-732             [MA93]  300       HMXB
# 4     12.686250 -73.268056  J0050.7-7316            V* DZ Tuc       HMXB
# 5     12.732500 -72.231944  J0051-722             [MA93]  413       HMXB
# ..          ...        ...               ...              ...        ...
# 229  315.887500  45.750000  J2103.5+4545      GSC 03588-00834       HMXB
# 233  324.891667  57.060000   2138+568             V* V490 Cep       HMXB
# 235  330.409167  50.167778   2202+501             BD+49  3718       HMXB
# 236  331.987500  54.518333   2206+543             BD+53  2790       HMXB
# 237  339.837083  61.274111  J2239.3+6116           4U 2238+60       HMXB
#
#      Astrosat_Flag  2.1555907092912467      dec2      dec1  2.934771137228465  \
# 0                0            0.143706 -1.288145 -1.288145           0.143706
# 2                0            0.213985 -1.271434 -1.271434           0.213985
# 3                0            0.215955 -1.277271 -1.277271           0.215955
# 4                0            0.221417 -1.278769 -1.278769           0.221417
# 5                0            0.222224 -1.260685 -1.260685           0.222224
# ..             ...                 ...       ...       ...                ...
# 229              0           -0.769908  0.798488  0.798488          -0.769908
# 233              0           -0.612756  0.995885  0.995885          -0.612756
# 235              0           -0.516457  0.875593  0.875593          -0.516457
# 236              0           -0.488910  0.951524  0.951524          -0.488910
# 237              0           -0.351909  1.069435  1.069435          -0.351909
#
#      ...  83.98801430742803  84.4284481616221  84.52433218740353  \
# 0    ...           0.143706          0.143706           0.143706
# 2    ...           0.213985          0.213985           0.213985
# 34   ...           1.370563          1.370563           1.370563
# 36   ...           1.398387          1.398387           1.398387
# 54   ...           1.645504          1.645504           1.645504
# 60   ...           2.044493          2.044493           2.044493
# ..   ...                ...               ...                ...
# 230  ...          -0.683984         -0.683984          -0.683984
# 231  ...          -0.654622         -0.654622          -0.654622
# 232  ...          -0.648230         -0.648230          -0.648230
# 234  ...          -0.590416         -0.590416          -0.590416
# 238  ...          -0.172053         -0.172053          -0.172053
#
#      85.05643944310529  85.39154265948821  86.50091756528711  \
# 1             0.195651           0.195651           0.195651
# 34            1.370563           1.370563           1.370563
# 36            1.398387           1.398387           1.398387
# 54            1.645504           1.645504           1.645504
# 60            2.044493           2.044493           2.044493
# ..                 ...                ...                ...
# 230          -0.683984          -0.683984          -0.683984
# 231          -0.654622          -0.654622          -0.654622
# 232          -0.648230          -0.648230          -0.648230
# 234          -0.590416          -0.590416          -0.590416
# 238          -0.172053          -0.172053          -0.172053
#
#      86.91412425697013  88.96914035938856  91.6669830506588       ra1
# 1             0.195651           0.195651          0.195651  0.195651
# 34            1.370563           1.370563          1.370563  1.370563
# 36            1.398387           1.398387          1.398387  1.398387
# 54            1.645504           1.645504          1.645504  1.645504
# 60            2.044493           2.044493          2.044493  2.044493
# ..                 ...                ...               ...       ...
# 230          -0.683984          -0.683984         -0.683984 -0.683984
# 231          -0.654622          -0.654622         -0.654622 -0.654622
# 232          -0.648230          -0.648230         -0.648230 -0.648230
# 234          -0.590416          -0.590416         -0.590416 -0.590416
# 238          -0.172053          -0.172053         -0.172053 -0.172053
#
# [121 rows x 248 columns]

# %%
fig1=plt.figure(figsize=(25,25))
GH=fig1.add_subplot(121, projection="mollweide",facecolor='black')
GH.scatter(h['ra1'],h['dec2'],c='hotpink')
GH.set_xlabel("RA")
GH.set_ylabel("DEC")
GH.grid(c='w')
GH.set(title="High Mass X-Ray Binaries")
GH.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in GH.get_xticklabels() + GH.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
GH
# Out:
# <MollweideAxesSubplot:title={'center':'High Mass X-Ray Binaries'}, xlabel='RA', ylabel='DEC'>

# %%
fig2=plt.figure(figsize=(25,25))
LH=fig2.add_subplot(122,projection="mollweide",facecolor='black')
LH.scatter(l['ra1'],l['dec2'],c='hotpink')
LH.set_xlabel("RA")
LH.set_ylabel("DEC")
LH.grid(c='w')
LH.set(title="Low Mass X-Ray Binaries")
LH.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in LH.get_xticklabels() + LH.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
LH
# Out:
# <MollweideAxesSubplot:title={'center':'Low Mass X-Ray Binaries'}, xlabel='RA', ylabel='DEC'>

# %%
p=df[df.Astrosat_Flag==0]
q=df[df.Astrosat_Flag==1]
fig3=plt.figure(figsize=(25,25))
F1=fig3.add_subplot(121,projection="mollweide",facecolor='black')
F1.scatter(p['ra1'],p['dec2'],c='hotpink')
F1.set_xlabel("RA")
F1.set_ylabel("DEC")
F1.grid(c='w')
F1.set(title="Flag==0")
F1.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in F1.get_xticklabels() + F1.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
F1
# Out:
# <MollweideAxesSubplot:title={'center':'Flag==0'}, xlabel='RA', ylabel='DEC'>

# %%
fig4=plt.figure(figsize=(25,25))
F2=fig4.add_subplot(122,projection="mollweide",facecolor='black')
F2.scatter(q['ra1'],q['dec2'],c='hotpink')
F2.set_xlabel("RA")
F2.set_ylabel("DEC")
F2.grid(c='w')
F2.set(title="Flag==1")
F2.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in F2.get_xticklabels() + F2.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
F2
# Out:
# <MollweideAxesSubplot:title={'center':'Flag==1'}, xlabel='RA', ylabel='DEC'>

# %%
fig5=plt.figure(figsize=(30,30))
all1=fig5.add_subplot(projection="mollweide",facecolor='black')
all1.scatter(h['ra1'],h['dec2'],c='white') #Plotting HMXB
all1.scatter(l['ra1'],l['dec2'],c='yellow') #Plotting LMXB
all1.set_xlabel("RA")
all1.set_ylabel("DEC")
all1.grid(c='w')
all1.set(title="All Subplots")
all1.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in all1.get_xticklabels() + all1.get_yticklabels():
    label.set_fontsize(18)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
all1
# Out:
# <MollweideAxesSubplot:title={'center':'All Subplots'}, xlabel='RA', ylabel='DEC'>

# %%
fig6=plt.figure(figsize=(30,30))
all2=fig6.add_subplot(projection="mollweide",facecolor='black')
all2.scatter(p['ra1'],p['dec2'],c='blue') #Plotting flag=0
all2.scatter(q['ra1'],q['dec2'],c='hotpink') #Plotting flag=1
all2.set_xlabel("RA")
all2.set_ylabel("DEC")
all2.grid(c='w')
all2.set(title="All Subplots")
all2.set_xticklabels(['-150','-120','-90','-60','-30','0','30','60','90','120','150'])
for label in all2.get_xticklabels() + all2.get_yticklabels():
    label.set_fontsize(18)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.8 ))
all2
# Out:
# <MollweideAxesSubplot:title={'center':'All Subplots'}, xlabel='RA', ylabel='DEC'>

# %%
h.iloc[0:,4]    #no. of HMXB
# Out:
# 0      HMXB
# 2      HMXB
# 3      HMXB
# 4      HMXB
# 5      HMXB
#        ...
# 229    HMXB
# 233    HMXB
# 235    HMXB
# 236    HMXB
# 237    HMXB
# Name: Final_Type, Length: 118, dtype: object

# %%
l.iloc[0:,4]  #no. of LMXB
# Out:
# 1      LMXB
# 34     LMXB
# 36     LMXB
# 54     LMXB
# 60     LMXB
#        ...
# 230    LMXB
# 231    LMXB
# 232    LMXB
# 234    LMXB
# 238    LMXB
# Name: Final_Type, Length: 121, dtype: object

# %%
df.loc[df.SIMBAD_Name=="Granat 1915+105"]   #coordinates of Granat 1915+105
# Out:
#              ra        dec       Source_Name      SIMBAD_Name Final_Type  \
# 213  288.820833  10.968333   1915+105         Granat 1915+105       HMXB
#
#      Astrosat_Flag  2.1555907092912467      dec2      dec1  2.934771137228465  \
# 213              1           -1.242311  0.191434  0.191434          -1.242311
#
#      ...  83.98801430742803  84.4284481616221  84.52433218740353  \
# 213  ...          -1.242311         -1.242311          -1.242311
#
#      85.05643944310529  85.39154265948821  86.50091756528711  \
# 213          -1.242311          -1.242311          -1.242311
#
#      86.91412425697013  88.96914035938856  91.6669830506588       ra1
# 213          -1.242311          -1.242311         -1.242311 -1.242311
#
# [1 rows x 248 columns]
